# %%
import pandas as pd
import mysql.connector as sql
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#dataframe creation
my_db = sql.connect(
    host='localhost',
    user='root',
    password='12345678',
    database='phone_pe_pulse'
)

cursor = my_db.cursor()

#aggregate_insurance_df
cursor.execute("SELECT * FROM aggregated_insurance")


table1= cursor.fetchall()

Aggre_insurance= pd.DataFrame(table1, columns=("States","Years","Quater","Transaction_type",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Aggre_insurance

# %%
#aggregate_transaction_df
cursor.execute("SELECT * FROM aggregated_transaction")


table2= cursor.fetchall()

Aggre_transaction= pd.DataFrame(table2, columns=("States","Years","Quater","Transaction_type",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Aggre_transaction

# %%
#aggregate_users_df
cursor.execute("SELECT * FROM aggregated_user")


table3= cursor.fetchall()

Aggre_user= pd.DataFrame(table3, columns=("States","Years","Quater","Brands",
                                                     "Transaction_count",
                                                     "Percentage"))

# %%
Aggre_user

# %%
#map_insurance_df
cursor.execute("SELECT * FROM map_insurance")


table4= cursor.fetchall()

Map_insurance= pd.DataFrame(table4, columns=("States","Years","Quater","Districts",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Map_insurance

# %%
#map_transactions_df
cursor.execute("SELECT * FROM map_transaction")


table5= cursor.fetchall()

Map_transaction= pd.DataFrame(table5, columns=("States","Years","Quater","Districts",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Map_transaction

# %%
#map_user_df
cursor.execute("SELECT * FROM map_users")


table6= cursor.fetchall()

Map_users= pd.DataFrame(table6, columns=("States","Years","Quater","Districts",
                                                     "RegisteredUsers",
                                                     "AppOpens"))

# %%
#top_insurance_df
cursor.execute("SELECT * FROM top_insurance")


table7= cursor.fetchall()

Top_insurance= pd.DataFrame(table7, columns=("States","Years","Quater","Pincodes",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Top_insurance

# %%
#top_transaction_df
cursor.execute("SELECT * FROM top_transaction")


table8= cursor.fetchall()

Top_transaction= pd.DataFrame(table8, columns=("States","Years","Quater","Pincodes",
                                                     "Transaction_count",
                                                     "Transaction_amount"))

# %%
Top_transaction

# %%
#top_user_df
cursor.execute("SELECT * FROM top_user")


table9= cursor.fetchall()

Top_user= pd.DataFrame(table9, columns=("States","Years","Quater","Pincodes",
                                                     "RegisteredUsers"))

# %%
Top_user
# Out:
#                  States  Years  Quater Pincodes  RegisteredUsers
# 0     Andaman & Nicobar   2018       1   744103             1608
# 1     Andaman & Nicobar   2018       1   744101             1108
# 2     Andaman & Nicobar   2018       1   744105             1075
# 3     Andaman & Nicobar   2018       1   744102             1006
# 4     Andaman & Nicobar   2018       1   744104              272
# ...                 ...    ...     ...      ...              ...
# 9995        West Bengal   2024       4   733134           169596
# 9996        West Bengal   2024       4   700059           169448
# 9997        West Bengal   2024       4   711302           146034
# 9998        West Bengal   2024       4   700150           142151
# 9999        West Bengal   2024       4   711106           142077
#
# [10000 rows x 5 columns]

# %%
# !pip3 install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in c:\users\avnsp\appdata\roaming\python\python314\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\avnsp\appdata\roaming\python\python314\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.17.0)
# Requirement already satisfied: colorama in c:\users\avnsp\appdata\roaming\python\python314\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\avnsp\appdata\roaming\python\python314\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\avnsp\appdata\local\programs\python\python314\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\avnsp\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def Transaction_amount_count_Y(year):
    tacy= Aggre_insurance[Aggre_insurance["Years"]== year]
    tacy.reset_index(drop= True, inplace=True)

    tacyg= tacy.groupby("States")["Transaction_count"].sum()
    tacyg.reset_index(inplace= True)

# %%
       year= st.selectbox("Select Year", Aggre_transaction["Years"].unique())
       st
       df2= Quarterly_analysis()
       df2= df2[df2["Years"]==year]
       fig2, ax2= plt.subplots()
       sns.lineplot(data=df2, x= "Quater",y="Transaction_count", marker="o", ax=ax2)
       plt.title(f"{year}")
       st.pyplot(fig2)
       st.divider()
